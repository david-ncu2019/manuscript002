# %%
from appgeopy import *
from my_packages import *
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %% [markdown]
# # compare `nojump` and `with_jump`

# %%
def read_and_plot(fpath):
    df = pd.read_csv(fpath, parse_dates=[0], index_col=[0])
    return df

# %%
df = read_and_plot(
    r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\modeled_nojump\group_byLayer_nojump\TUKU_modeled_grouped.csv"
)
df.plot()
# Out:
# <Axes: xlabel='datetime'>
