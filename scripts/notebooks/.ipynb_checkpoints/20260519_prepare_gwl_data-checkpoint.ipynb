# %%
from appgeopy import *
from my_packages import *

# %% [markdown]
# # STAGE 1

# %% [markdown]
# ## Export groundwater timeseries into feather file

# %% [raw]
# gwl_fpath = r"D:\1000_SCRIPTS\004_Project003\20251229_Gwater_Levels\20260108_GWL_CRFP_daily_modeled.h5"
#
# gwl_data, gwl_info = open_HDF5(gwl_fpath)
# gwl_data.keys()

# %% [raw]
# time_arr = pd.to_datetime(
#     [ele.decode("utf-8") for ele in gwl_data["daily_timestamp"]]
# )
# time_arr[:5]

# %% [raw]
# available_stations = [
#     key for key in gwl_data.keys() if isinstance(gwl_data[key], dict)
# ]
# available_stations[:5]

# %% [raw]
# output_fld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_timeseries"
#
# for select_station in tqdm(available_stations):
#     gwl_byStation = gwl_data[select_station]
#
#     available_wellcode = list(gwl_byStation.keys())
#
#     final_df = pd.concat(
#         [
#             pd.Series(
#                 data=gwl_byStation[select_wellcode]["model"],
#                 index=time_arr,
#                 name=select_wellcode,
#             )
#             for select_wellcode in available_wellcode
#         ],
#         axis=1,
#     )
#
#     final_df = final_df.reset_index()
#     final_df = final_df.rename({"index": "datetime"}, axis=1)
#     final_df.to_feather(
#         os.path.join(output_fld, f"{select_station}_gwl_timeseries.feather")
#     )

# %% [markdown]
# ## Assign English name to geospatial file
#
# to help AI easily recognize the feather stem

# %% [raw]
# all_well_info = pd.read_excel(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_info\gwl_allwells_flat.xlsx"
# )
#
# all_well_info = all_well_info.set_index("wellcode")
# all_well_info.head(3)

# %% [raw]
# geo_gwl = gpd.read_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_info_combined_screenAvail.gpkg",
#     read_geometry=False,
# )
#
# geo_gwl = geo_gwl.set_index("computer_id")
#
# geo_gwl["wellname_en"] = geo_gwl.index.map(all_well_info["station"])
#
# geo_gwl = geo_gwl.reset_index()
#
# geo_gwl = geo_gwl.loc[
#     :,
#     [
#         "survey_area_code",
#         "survey_area_name",
#         "well_name",
#         "wellname_en",
#         "computer_id",
#         "x_twd97",
#         "y_twd97",
#         "address",
#         "elev_m",
#         "casing_depth_m",
#         "screen_raw",
#         "data_period",
#         "source_page",
#     ],
# ]
#
# geo_gwl = convert_to_geodata(
#     df=geo_gwl, xcoord_col="x_twd97", ycoord_col="y_twd97", crs_epsg="epsg:3826"
# )
#
# geo_gwl.to_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_info_combined_screenAvail_v2.gpkg"
# )

# %% [markdown]
# ## Export MLCW + GWL
#
# I have asked AI to pair MLCW and closest GWL (with screen info)
#
# now I need to export these into a specific folder for further usage

# %% [raw]
# import os
#
# import pandas as pd
#
# # =================================================================
# # 1. SETUP MASTER PATHS, OUTPUT DIRECTORIES & CONSTANTS
# # =================================================================
#
# # Root workspace directory for data integration
# PROJECT_DIR = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2"
#
# # Destination folder where the synchronized, multi-layer timeline files will be saved
# OUTPUT_DIR = os.path.join(PROJECT_DIR, r"data\gwl\mlcw_gwl_timeseries")
#
# # Ensure the output subdirectory exists to prevent save errors later
# if not os.path.exists(OUTPUT_DIR):
#     os.makedirs(OUTPUT_DIR, exist_ok=True)
#
# # Master timeline file containing the exact dates of the satellite overpasses (InSAR)
# INSAR_TIMELINE_PATH = os.path.join(
#     PROJECT_DIR, r"data\insar\timeseries\mlcw_interp_insar_IDW_extend.feather"
# )
#
# # Relational mapping file linking compaction well stations to nearby aquifer layers
# LAYER_ASSIGNMENT_PATH = os.path.join(
#     PROJECT_DIR, r"data\gwl\gwl_to_mlcw_layer_assignment.csv"
# )
#
# # =================================================================
# # 2. EXTRACT INSAR TIMELINE CHECKLIST (TEMPORAL FILTER BASIS)
# # =================================================================
#
# # Load the satellite metadata to harvest target acquisition dates
# insar_master_df = pd.read_feather(INSAR_TIMELINE_PATH)
#
# # Reconstruct a complete date catalog: Add the designated initial baseline date
# # ('D20150116') to the rest of the available 'D'-prefixed column headers
# insar_date_columns = ["D20150116"] + [
#     col for col in insar_master_df.columns if col.startswith("D")
# ]
#
# # Strip the leading 'D' prefix and cast strings to real datetime objects.
# # This array acts as a master temporal mask to sample the daily groundwater data.
# insar_target_dates = pd.to_datetime([col[1:] for col in insar_date_columns])
#
# # =================================================================
# # 3. PARSE CROSS-REFERENCE MAP & CHOOSE TARGET STATION
# # =================================================================
#
# # Load the spreadsheet that cross-references compaction stations with aquifer layouts
# layer_mapping_df = pd.read_csv(LAYER_ASSIGNMENT_PATH)
#
# # Extract a unique catalog of all hydrogeological monitoring stations
# available_stations = layer_mapping_df["station"].unique()
#
# # Select the primary target station for processing (Index 0)
# # selected_station = available_stations[0]  # Expected Output: 'ANHE'
#
# for selected_station in available_stations:
#
#     # Isolate the specific rows containing geological layer assignments for this station
#     station_layer_subdf = layer_mapping_df.query("station == @selected_station")
#
#     # =================================================================
#     # 4. LOAD DAILY GROUNDWATER LEVEL (GWL) TIME SERIES
#     # =================================================================
#
#     # Identify the corresponding feather database file containing daily water records
#     associated_feather_files = station_layer_subdf["feather_file"].unique()
#
#     # Validation: Each station must map to exactly one unified temporal dataset
#     if len(associated_feather_files) == 1:
#         # Convert Unix/Web relative paths to Windows-compatible absolute paths
#         gwl_file_path = os.path.join(
#             PROJECT_DIR, associated_feather_files[0].replace("/", "\\")
#         )
#     else:
#         raise ValueError(
#             f"Expected exactly 1 feather file for tracking, got {len(associated_feather_files)}"
#         )
#
#     # Isolate the physical code name of the groundwater observation station from the file name
#     gwl_station_name = os.path.basename(gwl_file_path).split("_")[0]
#
#     # Load the high-frequency daily groundwater monitoring measurements
#     gwl_master_df = pd.read_feather(gwl_file_path)
#
#     # Ensure the time index is fully cast to Datetime objects to allow temporal alignment operations
#     gwl_master_df["datetime"] = pd.to_datetime(gwl_master_df["datetime"])
#     gwl_master_df = gwl_master_df.set_index("datetime")
#
#     # =================================================================
#     # 5. VERTICAL PROFILE EXTRACTION & TIMELINE DOWN-SAMPLING
#     # =================================================================
#
#     # Storage list to collect the processed time series column of each aquifer layer
#     layer_series_buffer = []
#
#     # Identify all distinct underground layers monitored at this station (e.g., F1, F2, F3)
#     available_layers = station_layer_subdf["layer"].unique()
#
#     # Loop through each geological layer to isolate and align its hydrogeological behavior
#     for current_layer in available_layers:
#
#         # 1. Retrieve the numeric mechanical well code that monitors the current target aquifer layer
#         assigned_well_code = str(
#             station_layer_subdf.query("layer == @current_layer")[
#                 "assigned_wellcode"
#             ].iloc[0]
#         ).zfill(8)
#
#         # 2. Extract the specific water column tracking this well code from the daily table
#         single_layer_ts = gwl_master_df.loc[:, [assigned_well_code]]
#
#         # 3. Construct a standard compound identifier showing: CompactionStation_GeologicalLayer_WaterStation_WellCode
#         # This prevents column naming conflicts during multi-station comparisons.
#         single_layer_ts.columns = [
#             f"{selected_station}_{current_layer}_{gwl_station_name}_{assigned_well_code}"
#         ]
#
#         # 4. Down-sample the continuous daily records to match the specific overpass instances
#         # of the InSAR radar. If a target date is missing in the source data, Pandas handles it with a NaN.
#         aligned_layer_ts = single_layer_ts.loc[insar_target_dates, :]
#
#         # 5. Cache the synchronized column for the final stacking process
#         layer_series_buffer.append(aligned_layer_ts)
#
#     # =================================================================
#     # 6. UNIFY AQUIFER HORIZONS & EXPORT STANDARDIZED FEATHER FILE
#     # =================================================================
#
#     # Bind the isolated layer columns side-by-side to construct a full vertical profile matrix
#     station_gwl_profile_df = pd.concat(layer_series_buffer, axis=1)
#
#     # Prepare the data matrix structure to meet strict Feather format requirements:
#     # Move the Datetime index back to an explicit column and reset the index pointers.
#     station_gwl_profile_df = station_gwl_profile_df.reset_index()
#     station_gwl_profile_df = station_gwl_profile_df.rename(
#         {"index": "datetime"}, axis=1
#     )
#
#     # Export the final consolidated table. The resulting dataset maps water levels directly
#     # against InSAR observations for subsidence correlation analysis.
#     output_file_name = f"{selected_station}_{gwl_station_name}.feather"
#     station_gwl_profile_df.to_feather(
#         os.path.join(OUTPUT_DIR, output_file_name)
#     )

# %% [markdown]
# ## Fill the missing timeseries at YIWU

# %% [raw]
# import os
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # =================================================================
# # 1. SMART ADAPTIVE DATA EXTRACTOR
# # =================================================================
# def extract_well_measurements(hdf5_path, station, well_code):
#     """
#     Extracts groundwater observations. Automatically adapts to:
#     1. Root date keys ('daily_timestamp' vs 'date')
#     2. Dictionary structural nesting ('measure/daily_value' vs 'original')
#     """
#     db, _ = open_HDF5(hdf5_path)
#     station_group = db[station]
#     well_group = station_group[well_code]
#
#     # --- Part 1: Auto-Detect Date Key ---
#     if "daily_timestamp" in db.keys():
#         raw_dates = db["daily_timestamp"]
#     elif "date" in db.keys():
#         raw_dates = db["date"]
#     else:
#         raise KeyError(f"No valid date key found in {os.path.basename(hdf5_path)}")
#
#     time_index = pd.to_datetime([d.decode("utf-8") for d in raw_dates])
#
#     # --- Part 2: Auto-Detect Structure Layout ---
#     if "measure" in well_group.keys():
#         # Layout A (Historical file): Deep nested structure
#         raw_values = well_group["measure"]["model"]
#     elif "model" in well_group.keys():
#         # Layout B (Modeled file): Flat structure pointing directly to 'original'
#         raw_values = well_group["model"]
#     else:
#         raise KeyError(f"Could not find 'measure' or 'original' keys under well {well_code}")
#
#     return pd.DataFrame(raw_values, index=time_index, columns=["water_level"])
#
# # =================================================================
# # 2. RUN DATA EXTRACTION (Both files now load safely)
# # =================================================================
# FILE_HISTORICAL = r"K:\PROJECT\001_CHOUSHUI_RIVER_BASIN\000_MONITORING_DATA\GROUNDWATER-LEVEL\DAVID\HDF5_FILE_HISTORY\20240828_GWL_CRFP_model.h5"
# FILE_MODELED = r"D:\1000_SCRIPTS\004_Project003\20251229_Gwater_Levels\20260108_GWL_CRFP_daily_modeled.h5"
#
# STATION = "YIWU"
# WELL = "09190122"
#
# # The extractor automatically parses the different internal layouts internally
# historical_df = extract_well_measurements(FILE_HISTORICAL, STATION, WELL)
# modeled_df = extract_well_measurements(FILE_MODELED, STATION, WELL)
#
# # =================================================================
# # 3. IDENTIFY HISTORICAL CUTOFF AND STITCH TIMELINES
# # =================================================================
#
# # Remove trailing NaN placeholders to locate the true end of historical tracking
# historical_cleaned = historical_df.dropna(subset=["water_level"])
# cutoff_date = historical_cleaned.index.max()
#
# # Slice the modeled extension data starting exactly one day after historical records stop
# future_extension = modeled_df.loc[cutoff_date + pd.Timedelta(days=1):]
#
# # Stitch the datasets end-to-end
# blended_profile_df = pd.concat([historical_cleaned, future_extension], axis=0)
#
# blended_profile_df.columns = [WELL]
#
# blended_profile_df = blended_profile_df.reset_index()
# blended_profile_df = blended_profile_df.rename({"index":"datetime"}, axis=1)
# blended_profile_df.to_feather(f"{STATION}_{WELL}.feather")
#
# # # =================================================================
# # # 4. PLOT VERIFICATION
# # # =================================================================
# # fig, ax = plt.subplots(figsize=(11, 5))
#
# # # FIX: Changed "darkslate_blue" to "darkslateblue"
# # blended_profile_df.loc["2015":].plot(
# #     ax=ax, color="darkslateblue", label="Spliced Continuous Time-Series", lw=1.5
# # )
#
# # ax.axvline(
# #     x=cutoff_date,
# #     color="crimson",
# #     linestyle="--",
# #     alpha=0.7,
# #     label=f"Splice Junction ({cutoff_date.strftime('%Y-%m-%d')})"
# # )
#
# # ax.set_title(f"Groundwater Observations Blended Time Series | Station: {STATION} | Well: {WELL}", fontweight="bold")
# # ax.set_ylabel("Water Elevation (m)")
# # ax.legend()
# # ax.grid(True, alpha=0.3)
#
# # plt.show()

# %% [markdown]
# ## Replace new YIWU to `mlcw_gwl_timeseries`

# %% [raw]
# def get_timeseries(fpath, date_arr):
#     df = pd.read_feather(fpath)
#     df["datetime"] = pd.to_datetime(df["datetime"])
#     df = df.set_index("datetime")
#     df = df.loc[date_arr, :]
#     return df

# %% [raw]
# mlcw_gwl_timeseries = pd.read_feather(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\mlcw_gwl_timeseries\YIWU_YIWU.feather"
# )
#
# mlcw_gwl_date = mlcw_gwl_timeseries["datetime"]
# mlcw_gwl_timeseries.head(3)

# %% [raw]
# for col in [
#     "YIWU_F1_YIWU_09190112",
#     "YIWU_F2_YIWU_09190112",
#     "YIWU_T1_YIWU_09190112",
# ]:
#     mlcw_gwl_timeseries.loc[:, col] = (
#         get_timeseries(fpath="YIWU_09190112.feather", date_arr=mlcw_gwl_date)
#         .iloc[:, 0]
#         .values
#     )
#
# mlcw_gwl_timeseries.loc[:, "YIWU_T2_YIWU_09190122"] = (
#     get_timeseries(fpath="YIWU_09190122.feather", date_arr=mlcw_gwl_date)
#     .iloc[:, 0]
#     .values
# )

# %% [raw]
# mlcw_gwl_timeseries.to_feather(r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\mlcw_gwl_timeseries\YIWU_YIWU.feather")

# %% [markdown]
# ## Extract leveling to get groundwater well elevation

# %% [raw]
# lev_data, lev_info = open_HDF5(
#     r"D:\1000_SCRIPTS\003_Project002\20241219_LevelingData_to_HDF5\20241220_All_LevelingData_LandSubsidence-wra-gov-tw.h5"
# )
#
# all_stations = list(lev_data.keys())
# all_stations[:3]

# %% [raw]
# def get_lev_timeseries(leveling_data, station_name):
#     date_arr = pd.to_datetime(
#         [ele.decode("utf-8") for ele in leveling_data[station_name]["date"]]
#     )
#     values_arr = leveling_data[station_name]["values"]
#     return pd.DataFrame(data=values_arr, index=date_arr, columns=[station_name])
#
#
# def get_elev_coords(leveling_info, station_name):
#     x_twd97 = leveling_info[station_name]["X_TWD97"]
#     y_twd97 = leveling_info[station_name]["Y_TWD97"]
#     return x_twd97, y_twd97

# %% [raw]
# output_table = pd.DataFrame(data=None, index=None)
#
# output_table = output_table.reset_index(drop=True)
#
# for select_station in tqdm(all_stations[:]):
#     # - - - - -
#     lev_ts = get_lev_timeseries(
#         leveling_data=lev_data, station_name=select_station
#     )
#     years_idx = lev_ts.index.year.tolist()
#
#     if 2023 in years_idx:
#         last_idx = lev_ts.last_valid_index()
#         lev_measure_2023 = lev_ts.loc[last_idx, :].squeeze()
#     else:
#         continue
#     # - - - - -
#     x_coord, y_coord = get_elev_coords(
#         leveling_info=lev_info, station_name=select_station
#     )
#
#     temp = pd.DataFrame(
#         data={
#             "station": [select_station],
#             "X_TWD97": [x_coord],
#             "Y_TWD97": [y_coord],
#             "elev_2023": [lev_measure_2023],
#         }
#     )
#
#     output_table = pd.concat([output_table, temp])
#
# output_table = output_table.reset_index(drop=True)
#
# output_table = convert_to_geodata(
#     df=output_table,
#     xcoord_col="X_TWD97",
#     ycoord_col="Y_TWD97",
#     crs_epsg="EPSG:3826",
# )
#
# output_table.to_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\temp\leveling_elev_2023.shp"
# )

# %% [markdown]
# ## export groundwater well info to shapefile
#
# then use it to extract the elevation from cokriging and taiwan dem 20m raster

# %% [raw]
# temp = pd.read_excel(r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\temp\gwl_allwells_flat.xlsx")
# geo_temp = convert_to_geodata(df=temp, xcoord_col="x_twd97", ycoord_col="y_twd97", crs_epsg="EPSG:3826")
# geo_temp.to_file(r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\temp\gwl_allwells.shp")

# %% [markdown]
# ## after elevation extraction, adjust the file, and export to machine-readable files

# %% [raw]
# temp = gpd.read_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\temp\gwl_allwells_leveling_DEM_Elev.shp"
# )
# temp = temp.rename(
#     {
#         "well_elev_m": "orig_well_elev_m",
#         "Predicted": "elev_leveling_m",
#         "RASTERVALU": "elev_DEM_m",
#     },
#     axis=1,
# )
# temp.to_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_info_combined_screenAvail_v3.gpkg"
# )

# %% [raw]
# temp.iloc[:, :-1].to_excel(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_info\gwl_allwells_flat_updated.xlsx",
#     index=False,
# )

# %% [markdown]
# # STAGE 2

# %% [markdown]
# ## Extract original MLCW grouped by layers

# %% [raw]
# mlcw_data, mlcw_info = open_HDF5(
#     r"D:\1000_SCRIPTS\003_Project002\20251111_GTWR003\1_PrepareDatasets\MLCW_3\20251230_MLCW_CRFP_Imputed_v4.h5"
# )
# available_stations = [
#     ele for ele in mlcw_data.keys() if isinstance(mlcw_data[ele], dict)
# ]
#
# savefolder = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\group_byLayer_orig"
#
# if not os.path.exists(savefolder):
#     os.makedirs(savefolder, exist_ok=True)
#
# # select_station = "TUKU"
# for select_station in tqdm(available_stations):
#     mlcw_byStation = mlcw_data[select_station]
#     datetime_arr = pd.to_datetime(
#         [ele.decode("utf-8") for ele in mlcw_byStation["date"]]
#     )
#     layer_arr = ["F1", "T1", "F2", "T2", "F3", "T3", "F4"]
#     compact_arr = mlcw_byStation["values"]["compactbylayer_FT"]
#
#     compact_df = pd.DataFrame(
#         data=compact_arr, columns=datetime_arr, index=layer_arr
#     )
#     compact_df = compact_df.T
#     compact_df = compact_df.reset_index()
#     compact_df = compact_df.rename({"index": "datetime"}, axis=1)
#
#     compact_df.to_csv(
#         os.path.join(savefolder, f"{select_station}_orig_grouped.csv"),
#         index=False,
#     )

# %% [markdown]
# ## Export MLCW + GWL
#
# the latest file pairing MLCW and appropriate groundwater levels : `..\data\gwl\gwl_to_mlcw_layer_assignment_v3.csv`

# %% [raw]
# import os
# from glob import glob
#
# import pandas as pd
#
# # =================================================================
# # 1. SETUP MASTER PATHS, OUTPUT DIRECTORIES & CONSTANTS
# # =================================================================
#
# # Define the root directory for the processing project
# PROJECT_DIR = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2"
#
# # Define the directory where the finalized groundwater datasets will be saved
# OUTPUT_DIR = os.path.join(PROJECT_DIR, r"data\gwl\mlcw_gwl_timeseries")
#
# # Automatically build the output directory if it does not exist yet
# if not os.path.exists(OUTPUT_DIR):
#     os.makedirs(OUTPUT_DIR, exist_ok=True)
#
# # Path to the lookup table matching compaction wells to aquifer screening layers
# LAYER_ASSIGNMENT_PATH = os.path.join(
#     PROJECT_DIR, r"data\gwl\gwl_to_mlcw_layer_assignment_v3.csv"
# )
#
# # =================================================================
# # 2. ITERATE THROUGH MONITORING STATIONS & EXTRACT TIME TARGETS
# # =================================================================
#
# # Load the master cross-reference configuration registry
# layer_registry_df = pd.read_csv(LAYER_ASSIGNMENT_PATH)
#
# # Identify every unique compaction well station location listed in the configuration file
# all_mlcw_stations = layer_registry_df["station"].unique()
#
# # Select the target station for processing (e.g., Index 0: 'ANHE')
# select_mlcw_station = all_mlcw_stations[0]
#
# # Core Loop: Process every single compaction station one by one
# for select_mlcw_station in tqdm(all_mlcw_stations):
#
#     # Search and locate the specific grouped layer file for the current station
#     mlcw_fpath = glob(
#         os.path.join(
#             PROJECT_DIR,
#             "data",
#             "mlcw",
#             "group_byLayer_orig",
#             f"{select_mlcw_station}*orig_grouped.csv",
#         )
#     )[0]
#
#     # Load the station table and treat the first column as a Datetime Index
#     mlcw_table = pd.read_csv(mlcw_fpath, parse_dates=[0], index_col=[0])
#
#     # Extract the timeline dates from this file to use as our target timeline framework
#     mlcw_timeline = mlcw_table.index
#
#     # Isolate all stratigraphic layer settings that match our current target station
#     station_profile_df = layer_registry_df.query(
#         "station == @select_mlcw_station"
#     )
#
#     # =================================================================
#     # 3. EXTRACTION, TEMPORAL ALIGNMENT, AND HORIZON SAMPLING
#     # =================================================================
#
#     # Identify all underground layers monitored at this specific well station
#     monitored_layers = station_profile_df["layer"].tolist()
#
#     # Select the primary layer to extract tracking metadata for (e.g., Index 0: 'F1')
#     # stratigraphy_layer = monitored_layers[0]
#
#     # Sub-Loop: Process each individual geological layer for the current station
#     for stratigraphy_layer in tqdm(monitored_layers):
#
#         # Isolate the explicit configuration settings row for this specific layer-station unit
#         layer_config_df = station_profile_df.query(
#             "layer == @stratigraphy_layer"
#         )
#
#         # Extract the identification code of the well, and pad with leading zeros to make it an 8-digit text string
#         gwl_wellcode = str(
#             layer_config_df["assigned_wellcode"].squeeze()
#         ).zfill(8)
#
#         # Locate the daily water level dataset file mapped to this specific layer unit
#         gwl_feather_fpath = glob(
#             os.path.join(PROJECT_DIR, layer_config_df["feather_file"].squeeze())
#         )[0]
#
#         # Parse the filename string to determine the physical code name of the groundwater station
#         gwl_station = os.path.basename(gwl_feather_fpath).split("_")[0]
#
#         # Read the raw daily water level time series from the feather database
#         gwl_timeseries = pd.read_feather(gwl_feather_fpath)
#
#         # Ensure the date column contains true Datetime objects and set it as the table row index
#         gwl_timeseries["datetime"] = pd.to_datetime(gwl_timeseries["datetime"])
#         gwl_timeseries = gwl_timeseries.loc[
#             gwl_timeseries.first_valid_index() :, :
#         ]
#
#         gwl_timeseries = gwl_timeseries.set_index("datetime")
#
#         mutual_timeline = gwl_timeseries.index.intersection(mlcw_timeline)
#
#         # Temporal Alignment: Reindex the daily records to match only the target timeline framework
#         gwl_timeseries_byWellCode = gwl_timeseries.loc[
#             mutual_timeline, [gwl_wellcode]
#         ]
#
#         # Generate a descriptive identifier compound: CompactionStation_WaterStation_WellCode
#         new_colname = f"{select_mlcw_station}_{gwl_station}_{gwl_wellcode}"
#
#         # Apply the tracking name directly to the column header
#         gwl_timeseries_byWellCode = gwl_timeseries_byWellCode.rename(
#             {gwl_wellcode: new_colname}, axis=1
#         )
#
#         # Flatten the Datetime index back into a column to comply with Feather saving rules
#         gwl_timeseries_byWellCode = gwl_timeseries_byWellCode.reset_index()
#
#         # Export the aligned time-series segment into a standalone feather file
#         gwl_timeseries_byWellCode.to_feather(
#             os.path.join(OUTPUT_DIR, new_colname + ".feather")
#         )

# %% [markdown]
# # STAGE 3

# %% [markdown]
# ## investigate and fill missing GWL data

# %% [raw]
# current_gwl_fld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_timeseries"
#
# gwl_files = glob(os.path.join(current_gwl_fld, "*.feather"))
# gwl_files[:3]

# %% [raw]
# # select_gwl = gwl_files[0]
#
# cache = {
#     "station": [],
#     "wellcode": [],
#     "start_datetime": [],
#     "end_datetime": [],
#     "start_year": [],
#     "end_year": [],
# }
#
# for select_gwl in tqdm(gwl_files):
#     station_name = os.path.basename(select_gwl).split("_")[0]
#
#     df = pd.read_feather(select_gwl)
#     try:
#         df["datetime"] = pd.to_datetime(df["datetime"])
#         df = df.set_index("datetime")
#     except:
#         pass
#
#     all_columns = df.columns
#
#     # select_col = all_columns[0]
#     for select_col in all_columns:
#
#         df_byCol = df.loc[:, select_col]
#
#         first_valid_datetime = df_byCol.first_valid_index()
#         last_valid_datetime = df_byCol.last_valid_index()
#
#         first_year = first_valid_datetime.year
#         last_year = last_valid_datetime.year
#
#         for key_name, var_name in zip(
#             cache.keys(),
#             [
#                 station_name,
#                 select_col,
#                 first_valid_datetime,
#                 last_valid_datetime,
#                 first_year,
#                 last_year,
#             ],
#         ):
#             cache[key_name].append(var_name)
#
# output_table = pd.DataFrame(cache)
# output_table.head(3), output_table.tail(3)

# %% [raw]
# output_table.to_excel("gwl_data_info.xlsx", index=False)

# %% [markdown]
# ## fill missing groundwater level values

# %%
def hdf5_to_df(hdf5_data, select_station):
    date_arr = pd.to_datetime(
        [ele.decode("utf-8") for ele in hdf5_data["date"]]
    )
    cols = list(hdf5_data[select_station].keys())

    gwl_cache = {
        wellcode: hdf5_data[select_station][wellcode]["measure"]["model"]
        for wellcode in cols
    }
    df = pd.DataFrame(data=gwl_cache, index=date_arr)
    return df


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -


def feather_to_df(fpath):
    df = pd.read_feather(fpath)
    df["datetime"] = pd.to_datetime(df["datetime"])
    df = df.set_index("datetime")
    return df


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def patch_column_gaps(df, column_mapping, inplace=True):
    """
    Fills missing values (NaN) in multiple target columns using their respective
    backup columns within the same DataFrame.

    Parameters:
    -----------
    df : pandas.DataFrame
        The DataFrame containing all columns.
    column_mapping : dict
        A dictionary where keys are target columns and values are backup columns.
        Format: {"target_col_1": "backup_col_1", "target_col_2": "backup_col_2"}
    inplace : bool, default True
        If True, modifies the DataFrame directly. If False, returns a modified copy.

    Returns:
    --------
    pandas.DataFrame or None
    """
    if not inplace:
        df = df.copy()

    # Loop through the dictionary and apply .fillna() to each pair automatically
    for target_col, backup_col in column_mapping.items():
        df[target_col] = df[target_col].fillna(df[backup_col])

    if not inplace:
        return df


# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
def patch_gaps_from_external_source(
    target_df, source_df, column_mapping, inplace=True
):
    """
    Fills missing values (NaN) in a target DataFrame using matching chronological
    values from columns in an external source DataFrame.

    Parameters:
    -----------
    target_df : pandas.DataFrame
        The primary DataFrame containing gaps that need to be filled.
    source_df : pandas.DataFrame
        The external source DataFrame containing the backup data columns.
    column_mapping : dict
        A dictionary mapping target column names to their external source column names.
        Format: {"target_well_code": "external_source_well_code"}
    inplace : bool, default True
        If True, modifies the target DataFrame directly. If False, returns a modified copy.

    Returns:
    --------
    pandas.DataFrame or None
    """
    if not inplace:
        target_df = target_df.copy()

    # Loop through the map and patch using the corresponding external column
    for target_col, source_col in column_mapping.items():
        # Pandas automatically aligns the values by their Datetime index matching rows
        target_df[target_col] = target_df[target_col].fillna(
            source_df[source_col]
        )

    if not inplace:
        return target_df

# %% [markdown]
# ## open file

# %% [raw]
# # take too long time to fill missing values manually, so I export to
# well_df = pd.read_excel(r"gwl_data_info_v2.xlsx")
# available_stations = well_df["station"].unique()
# len(available_stations)
#
# savefolder = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\old_well_timeseries"
# for select_station in available_stations[:]:
#     hdf5_df = hdf5_to_df(hdf5_data=h5_gwl_data, select_station=select_station)
#     hdf5_df = hdf5_df.reset_index(drop=False)
#     hdf5_df = hdf5_df.rename({"index":"datetime"}, axis=1)
#     hdf5_df.to_feather(
#         os.path.join(savefolder, f"{select_station}_old_timeseries.feather")
#     )

# %%
hdf5_fpath = r"D:\1000_SCRIPTS\002_Project001\20240825_Model_GWL_fromHDF5\20240828_GWL_CRFP_model.h5"

h5_gwl_data, _ = gwatertools.open_HDF5(hdf5_fpath)

# %%
topfolder = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_timeseries"

select_station = "FANGCAO"
fpath = os.path.join(topfolder, f"{select_station}_gwl_timeseries.feather")


hdf5_df = hdf5_to_df(hdf5_data=h5_gwl_data, select_station=select_station)
feather_df = feather_to_df(fpath)

# %%
feather_df.head(5)

# %%
hdf5_df.head(5)

# %% [markdown]
# ## visualize

# %%
# feather_df.iloc[:, 0::2].plot()
feather_df.iloc[:, :].plot()

# %% [raw]
# feather_df.iloc[:, 1::2].plot()

# %%
hdf5_df.iloc[:, :].plot()

# %% [raw]
# hdf5_df.iloc[:, 1::2].plot()

# %%
feather_df.columns

# %% [raw]
# hdf5_df.columns

# %% [markdown]
# ## fill missing

# %% [markdown]
# ### self filling

# %%
# =================================================================
# SMART EXAMPLE USAGE
# =================================================================

# Define all your well dependencies clearly in one dictionary mapping
WELL_PATCH_MAP = {
    "09040212": "09040211",  # Target: 112, Backup: 111
    "09040222": "09040221",  # Target: 122, Backup: 121
    # "07230232": "07230231",  # Target: 122, Backup: 121
    # "07230242": "07230241",  # Target: 122, Backup: 121
}

# Process all updates simultaneously in a single line
final_updated_df = patch_column_gaps(feather_df, WELL_PATCH_MAP, inplace=False)

# %% [markdown]
# ### cross filling

# %% [raw]
# # Define which column in your primary dataframe maps to which column in your external source dataframe
# CROSS_DF_WELL_MAP = {
#     "09010112": "09010112",  # Target column in target_df : Backup column in source_df
#     "09010122": "09010122",
#     "09010132": "09010132",
#     "09010142": "09010142",
# }
#
# # Run the external patching tool safely
# completed_feather_df = patch_gaps_from_external_source(
#     # target_df=feather_df,
#     # source_df=hdf5_df,
#     target_df=hdf5_df,
#     source_df=feather_df,
#     column_mapping=CROSS_DF_WELL_MAP,
#     inplace=False,
# )

# %%
final_updated_df.iloc[:, :].plot()

# %% [raw]
# completed_feather_df.iloc[:, :].plot()
# # feather_df.plot()

# %% [markdown]
# ### save output

# %%
final_updated_df.to_feather(fpath)

# %% [raw]
# completed_feather_df.to_feather(fpath)
