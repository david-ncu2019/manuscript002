# %% [markdown]
# # import library

# %%
from appgeopy import *
from my_packages import *
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %% [markdown]
# # Export information of geodetic data sets

# %% [markdown]
# ## GPS data

# %% [markdown]
# ### move GPS stations within InSAR frame into our working directory

# %% [raw]
# # - - - - - - - - - - - - - - - - - - - - -
# gps_source_fld = (
#     r"D:\1000_SCRIPTS\005_SideWork\20260426_download_GPS_data\formatted_output"
# )
# dest_fld = r"GPS_timeseries/"
# # - - - - - - - - - - - - - - - - - - - - -
# gps_insarframe = gpd.read_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\GPS_data\InSARframe_GPS_TWD97.shp",
#     read_geometry=False,
# )
# # - - - - - - - - - - - - - - - - - - - - -
# all_gps_stations = gps_insarframe["station_co"].tolist()
#
# station = all_gps_stations[0]
#
# for station in all_gps_stations:
#     search_file = glob(os.path.join(gps_source_fld, f"{station}*.csv"))
#     if search_file:
#         src_fpath = search_file[0]
#         base = os.path.basename(src_fpath)
#         dst_fpath = os.path.join(dest_fld, base)
#         shutil.copy2(src_fpath, dst_fpath)

# %% [markdown]
# ### export start date, end date, coordinates

# %% [raw]
# # - - - - - - - - - - - - - - - - - - - - -
# gps_insarframe = gpd.read_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\GPS_data\InSARframe_GPS_TWD97.shp",
#     read_geometry=False,
# )
# gps_insarframe = gps_insarframe.iloc[:, 1:5]
# gps_insarframe = gps_insarframe.set_index("station_co")
# # - - - - - - - - - - - - - - - - - - - - -
# gps_file_fld = r"GPS_timeseries/"
# all_gps_files = glob(os.path.join(gps_file_fld, "*.csv"))
# # - - - - - - - - - - - - - - - - - - - - -
# output_table = pd.DataFrame(data=None, index=None)
# # - - - - - - - - - - - - - - - - - - - - -
# # f = all_gps_files[0]
# for f in all_gps_files[:]:
#     station = os.path.basename(f).split("_")[0]
#     gps_bySTATION = gps_insarframe.loc[[station],]
#
#     try:
#         df = pd.read_csv(f, index_col=[1], parse_dates=[1])
#         gps_bySTATION["start_date"] = df.first_valid_index()
#         gps_bySTATION["end_date"] = df.last_valid_index()
#         gps_bySTATION["duration"] = (
#             df.last_valid_index() - df.first_valid_index()
#         ).days
#         gps_bySTATION["num_of_obs"] = df["dU"].notnull().count()
#         output_table = pd.concat([output_table, gps_bySTATION])
#     except Exception as e:
#         print(station, e)
#         pass
#
# output_table.to_csv("GPS_data_timeline.csv", index=True)

# %% [markdown]
# ## MLCW data

# %% [raw]
# mlcw_gdf = gpd.read_file(
#     r"D:\002_DATA\HSU_YARU_PROF\Yaru_work\mlcw_data_DavidNCU\mlcw_stations_TWD97.shp",
#     read_geometry=False,
# )
# mlcw_gdf = mlcw_gdf.set_index("Ename")
# mlcw_gdf = mlcw_gdf.loc[:, ["X_WGS84", "Y_WGS84"]]
# mlcw_gdf = mlcw_gdf.rename({"X_WGS84": "long", "Y_WGS84": "lat"}, axis=1)
# # - - - - - - - - - - - - - - - - - - - - -
# mlcw_file_fld = "MLCW_timeseries/"
# mlcw_files = glob(os.path.join(mlcw_file_fld, "*.csv"))
# # - - - - - - - - - - - - - - - - - - - - -
# output_table = pd.DataFrame(data=None, index=None)
# # - - - - - - - - - - - - - - - - - - - - -
# # f = mlcw_files[0]
# for f in mlcw_files:
#
#     station_name = os.path.basename(f).replace("_ringbyring.csv", "")
#
#     df = pd.read_csv(f, index_col=[0], parse_dates=[0])
#
#     mlcw_bySTATION = mlcw_gdf.loc[[station_name], :]
#
#     mlcw_bySTATION["start_date"] = df.first_valid_index()
#     mlcw_bySTATION["end_date"] = df.last_valid_index()
#     mlcw_bySTATION["duration"] = (
#         df.last_valid_index() - df.first_valid_index()
#     ).days
#     mlcw_bySTATION["num_of_obs"] = df.iloc[:, 0].notnull().count()
#     output_table = pd.concat([output_table, mlcw_bySTATION])
#
# output_table.to_csv("MLCW_data_timeline.csv")

# %% [markdown]
# ## InSAR data

# %% [raw]
# insar_gdf = gpd.read_file(
#     "InSAR_timeries/mlcw_interp_insar_IDW.shp", read_geometry=False
# )
# insar_gdf = insar_gdf.set_index("Ename")
# insar_gdf = insar_gdf.loc[:, "D20150301":]
# insar_gdf.columns = pd.to_datetime([ele[1:] for ele in insar_gdf.columns])
# insar_gdf.index.name = "datetime"
# insar_gdf = insar_gdf.T
#
# insar_gdf.to_csv("InSAR_measures_at_MLCW.csv", index=True)

# %% [markdown]
# # MLCW - GPS pairs

# %% [markdown]
# ## Find closest neighbors
# First we need to find the closet GPS station to each MLCW station

# %% [raw]
# gps_data = gpd.read_file("GPS_data/TGM_GPS_TWD97.shp")
# # gps_data.explore(
# #     column="height",
# #     cmap="terrain",
# #     legend=True,
# #     marker_kwds=dict(radius=4, opacity=0.8, weight=1.5, fillOpacity=0.7),
# #     popup=True,
# #     tiles="OpenStreetMap",
# # )

# %% [raw]
# mlcw_data = gpd.read_file(
#     r"D:\002_DATA\HSU_YARU_PROF\Yaru_work\mlcw_data_DavidNCU\mlcw_stations_TWD97.shp"
# )
# # mlcw_data.explore(
# #     marker_kwds=dict(radius=10, opacity=0.8, weight=1.5, fillOpacity=0.7),
# #     popup=True,
# #     tiles="OpenStreetMap",
# # )

# %% [raw]
# # Use sjoin_nearest
# result = gpd.sjoin_nearest(
#     left_df=mlcw_data.loc[:, ["Code", "Ename", "geometry"]],
#     right_df=gps_data.loc[:, ["station_co", "geometry"]],
#     how="left",
#     distance_col="distance",
# )
# show(result)

# %% [raw]
# result.to_excel("MLCW_GPS_pairs.xlsx", index=False)

# %% [markdown]
# ## Move GPS files to current directory

# %% [raw]
# gps_stations = station_pairs["station_co"].tolist()
# gps_source_fld = (
#     r"D:\1000_SCRIPTS\005_SideWork\20260426_download_GPS_data\formatted_output"
# )
# dest_fld = "GPS_timeseries/"
#
# for gps in tqdm(gps_stations):
#     found_fpath = glob(os.path.join(gps_source_fld, f"{gps}*"))
#     if found_fpath:
#         base = os.path.basename(found_fpath[0])
#         shutil.copy2(src=found_fpath[0], dst=os.path.join(dest_fld, base))
#
# len(set(gps_stations))

# %% [markdown]
# ## Only keep the GPS timeseries last longer than 5 years

# %% [raw]
# gps_fld = "GPS_timeseries/"
# gps_csv_files = glob(os.path.join(gps_fld, "*.csv"))
# gps_csv_files[:3]

# %% [raw]
# # file = gps_csv_files[0]
# cache = {"STATION": [], "First": [], "Last": [], "Duration_days": []}
# for file in gps_csv_files:
#     station_name = os.path.basename(file).split(".")[0].split("_")[0]
#
#     df = pd.read_csv(file, usecols=[1, 4], index_col=[0], parse_dates=[0])
#     first_index = df.first_valid_index()
#     last_index = df.last_valid_index()
#     duration = (last_index - first_index).days
#     for key, value in zip(
#         cache.keys(), [station_name, first_index, last_index, duration]
#     ):
#         cache[key].append(value)
#
# temp = pd.DataFrame(cache)
# temp["Years"] = np.int32(temp.iloc[:, -1] / 365.25)

# %% [raw]
# show(temp)

# %% [markdown]
# ## Model GPS dU timeseries

# %% [markdown]
# ### model GPS dU using `gps_decompose.py`
#
# **(Deprecated)**
# This is my previous program, when I haven't enhanced it with `w-stat`

# %% [raw]
# gps_source_fld = "GPS_timeseries/"
# gps_output_fld = "GPS_modeled/"
#
# # Get all subdirectories
# output_fld = [
#     f for f in glob(os.path.join(gps_source_fld, "*")) if os.path.isdir(f)
# ]
#
# for select_fld in tqdm(output_fld):
#     base = os.path.basename(select_fld)
#
#     # Read CSV
#     csv_file = glob(os.path.join(select_fld, "*.csv"))[0]
#     df = pd.read_csv(csv_file, index_col=0, parse_dates=[0])
#
#     # Create output dataframe
#     df_output = df[["dU_trend"]].copy()
#
#     # Handle jump column
#     jump_col = df["dU_jump"] if "dU_jump" in df.columns else 0
#     df_output["no_jump"] = df["dU"] - jump_col
#     df_output["modeled"] = df["dU_model"] - jump_col
#
#     # Save output
#     output_file = os.path.join(
#         gps_output_fld, base.replace("neu", "model") + ".csv"
#     )
#     df_output.to_csv(output_file)

# %% [markdown]
# ### model GPS dU using `appsigsolv`
#
# I have run `python batch_process_GPS_dU.py`, which activate the `python -m appsigsolv decompose` to model the raw GPS timeseries. then I will extract the primary signals and save the file in `GPS_modeled` folder

# %% [raw]
# gps_decompose_fld = "GPS_decomposition/"
# gps_output_fld = "GPS_modeled"
#
# if not os.path.exists(gps_output_fld):
#     os.makedirs(gps_output_fld, exist_ok=True)
#
# files = glob(os.path.join(gps_decompose_fld, "*", "*csv"))
#
# # f = files[-7]
# for f in tqdm(files):
#     station_name = os.path.basename(f).split("_")[0]
#
#     df = pd.read_csv(f, index_col=[0], parse_dates=[0])
#     df_model = pd.DataFrame(data=None, index=None)
#     df_model["orig"] = df["dU"]
#     # df_model["trend"] = df["dU_trend"]
#     jump_col = df["dU_jump"] if "dU_jump" in df.columns else 0
#     df_model["orig_nojump"] = df["dU"] - jump_col
#     df_model["modeled"] = df["dU_model"] - jump_col
#
#     df_model.to_csv(os.path.join(gps_output_fld, f"{station_name}_model.csv"))

# %% [markdown]
# ## Model MLCW

# %% [markdown]
# ### run `appsigsolv`
#
# **2026/05/02**:
#
# I want to export these timeseries into CSV file so that `appsigsolv` can model the signal at each ring (run again on 2026/5/8)

# %% [raw]
# savefolder = "MLCW_timeseries/"
#
# mlcw_data, mlcw_info = open_HDF5(
#     r"D:\1000_SCRIPTS\003_Project002\20251111_GTWR003\1_PrepareDatasets\MLCW_3\20251230_MLCW_CRFP_Imputed_v4.h5"
# )
#
# available_stations = [
#     key for key in mlcw_data.keys() if isinstance(mlcw_data[key], dict)
# ]
#
# # select_station = "TUKU"
#
# for select_station in tqdm(available_stations[:]):
#
#     mlcw_bySTATION = mlcw_data[select_station]
#
#     depth_arr = [str(round(ele, 3)) for ele in mlcw_bySTATION["depth"]]
#     date_arr = pd.to_datetime([x.decode() for x in mlcw_bySTATION["date"]])
#
#     ringbyring_arr = mlcw_bySTATION["values"]["ringbyring"]
#
#     mlcw_df = pd.DataFrame(
#         data=ringbyring_arr, index=depth_arr, columns=date_arr
#     )
#
#     mlcw_df = mlcw_df.T
#     mlcw_df.index.name = "datetime"
#
#     mlcw_df.iloc[:, :].to_csv(
#         os.path.join(savefolder, f"{select_station}_ringbyring.csv")
#     )

# %% [markdown]
# ### Export modeled signal to a new folder

# %% [raw]
# mlcw_decompose_fld = "MLCW_decomposition/"
# mlcw_output_fld = "MLCW_modeled"
#
# if not os.path.exists(mlcw_output_fld):
#     os.makedirs(mlcw_output_fld, exist_ok=True)
#
# folders = [
#     f for f in glob(os.path.join(mlcw_decompose_fld, "*")) if os.path.isdir(f)
# ]
#
# # fld = folders[0]
# for fld in tqdm(folders[:]):
#
#     base = os.path.basename(fld)
#
#     files = glob(os.path.join(fld, "*.csv"))
#
#     df_model = pd.DataFrame(data=None)
#
#     # f = files[0]
#
#     for idx, f in enumerate(files):
#         df = pd.read_csv(f, parse_dates=[0], index_col=[0])
#         # df = df * 1000
#
#         if idx == 0:
#             df_model.index = df.index
#
#         colname = os.path.basename(f).split("_")[-1].replace(".csv", "")
#
#         jump_col = (
#             df[f"{colname}_jump"] if f"{colname}_jump" in df.columns else 0
#         )
#
#         df_model[f"{colname}"] = df[f"{colname}_model"]
#
#     df_model = df_model[
#         [str(ele) for ele in sorted(df_model.columns.map(lambda x: eval(x)))]
#     ]
#     df_model.to_csv(os.path.join(mlcw_output_fld, f"{base}.csv"))

# %% [markdown]
# ## Check timeseries modeled GPS and MLCW

# %% [markdown]
# 2026/05/03:
#
# Now I need to compare the timeseries between modeled GPS and modeled MLCW (sum all rings),
# then get the compaction percentage MLCW over GPS

# %% [markdown]
# **check MLCW total compaction over GPS**

# %% [raw]
# # ---------------------------------------------------------
# # 1. Setup paths and input parameters
# # ---------------------------------------------------------
# MLCW_MODEL_FLD = "MLCW_modeled/"
# GPS_MODEL_FLD = "GPS_modeled/"
# SAVEFIG_FLD = "MLCW_GPS_figs/"
# PAIRS_EXCEL = "MLCW_GPS_pairs.xlsx"
#
# # ---------------------------------------------------------
# # 2. Find corresponding GPS station
# # ---------------------------------------------------------
# # Read the pairs and get the corresponding GPS station name
# station_pairs = pd.read_excel(PAIRS_EXCEL, index_col=[1])
#
#
# available_stations = station_pairs.index.tolist()
#
# # Select the MLCW station to analyze
# # select_mlcw = "TUKU"
# for select_mlcw in tqdm(available_stations):
#     try:
#         gps_byMLCW = station_pairs.loc[select_mlcw, "station_co"]
#         # ---------------------------------------------------------
#         # 3. Load Data
#         # ---------------------------------------------------------
#         # Find the first matching CSV for the MLCW station and read it
#         mlcw_csv_path = glob(
#             os.path.join(MLCW_MODEL_FLD, f"*{select_mlcw}*csv")
#         )[0]
#         mlcw_df = (
#             pd.read_csv(mlcw_csv_path, index_col=[0], parse_dates=[0]) * 1000
#         )
#
#         # Find the first matching CSV for the GPS station and read it
#         gps_csv_path = glob(os.path.join(GPS_MODEL_FLD, f"*{gps_byMLCW}*csv"))[
#             0
#         ]
#         gps_df = (
#             pd.read_csv(gps_csv_path, index_col=[0], parse_dates=[0]) * 1000
#         )
#
#         # ---------------------------------------------------------
#         # 4. Align Data to Mutual Timeframe
#         # ---------------------------------------------------------
#         def get_aligned_df(df, mutual_time):
#             """
#             Filter dataframe by mutual dates and shift values so the
#             first observation starts at 0 for a clean comparison baseline.
#             """
#             new_df = df.loc[mutual_time]
#             new_df = new_df.subtract(new_df.iloc[0, :], axis=1)
#             return new_df
#
#         # Find intersection of dates between MLCW and GPS
#         mutual_dates = mlcw_df.index.intersection(gps_df.index)
#
#         # Align both dataframes to the mutual dates
#         aligned_mlcw = get_aligned_df(df=mlcw_df, mutual_time=mutual_dates)
#         aligned_gps = get_aligned_df(df=gps_df, mutual_time=mutual_dates)
#
#         # Sum all components for MLCW to get total displacement
#         aligned_mlcw_arr = aligned_mlcw.sum(axis=1)
#
#         # Extract the 'modeled' column for GPS
#         aligned_gps_arr = aligned_gps["modeled"]
#
#         # ---------------------------------------------------------
#         # 5. Visualize with appgeopy
#         # ---------------------------------------------------------
#         # Create 2 subplots: Top (larger) for displacement, Bottom (smaller) for the ratio
#         fig, (ax1, ax2) = plt.subplots(
#             nrows=2,
#             ncols=1,
#             figsize=(11.7, 8.27),  # A4 landscape from appgeopy's BASE_SIZE
#             gridspec_kw={"height_ratios": [3, 1]},
#             sharex=True,
#         )
#
#         # --- Top Plot: Displacement Comparison ---
#         ax1.plot(
#             aligned_mlcw_arr.index,
#             aligned_mlcw_arr.values,
#             label="MLCW",
#             color="blue",
#             linewidth=2,
#         )
#         ax1.plot(
#             aligned_gps_arr.index,
#             aligned_gps_arr.values,
#             label="GPS",
#             color="orange",
#             linewidth=2,
#         )
#
#         # Use appgeopy's configure_axis for styling the top plot
#         visualize.configure_axis(
#             ax1,
#             ylabel="Displacement (mm)",
#             title=f"Deformation Comparison: MLCW ({select_mlcw}) vs GPS ({gps_byMLCW})",
#         )
#         visualize.configure_legend(ax1, frameon=True)
#
#         # --- Bottom Plot: Ratio ---
#         ratio_arr = aligned_mlcw_arr / aligned_gps_arr
#         ax2.plot(
#             ratio_arr.index,
#             ratio_arr.values,
#             label="MLCW / GPS Ratio",
#             color="red",
#             linestyle="--",
#         )
#
#         # Add a horizontal line at 1.0 to show perfect agreement
#         ax2.axhline(1.0, color="black", linewidth=1, linestyle=":")
#         ax2.set_ylim(bottom=-1.5, top=1.5)
#
#         # Use appgeopy's configure_axis for styling the bottom plot
#         visualize.configure_axis(ax2, xlabel="Date", ylabel="Ratio")
#         visualize.configure_legend(ax2, frameon=True, loc="lower left")
#
#         # Auto-format dates for better x-axis readability and tighten layout
#         fig.autofmt_xdate(rotation=45, ha="center")
#         fig.tight_layout()
#
#         visualize.save_figure(
#             fig=fig,
#             savepath=os.path.join(SAVEFIG_FLD, f"{select_mlcw}_mlcw_gps.png"),
#         )
#         # Show the plot
#         # plt.show()
#         plt.close()
#
#         # ---------------------------------------------------------
#         # 6. Calculate Slopes and Save to JSON
#         # ---------------------------------------------------------
#         import json
#
#         from appgeopy.analysis import get_linear_trend
#
#         # get_linear_trend returns (trend_series, slope_per_point) in mm/point
#         _, mlcw_slope_per_point = get_linear_trend(aligned_mlcw_arr)
#         _, gps_slope_per_point = get_linear_trend(aligned_gps_arr)
#
#         # Convert slope from mm/point to cm/year
#         total_days = (mutual_dates[-1] - mutual_dates[0]).days
#         total_years = total_days / 365.25
#         num_intervals = len(mutual_dates) - 1
#
#         if total_years > 0 and num_intervals > 0:
#             mlcw_slope_cm_yr = (
#                 mlcw_slope_per_point * num_intervals / total_years * 0.1
#             )
#             gps_slope_cm_yr = (
#                 gps_slope_per_point * num_intervals / total_years * 0.1
#             )
#
#             slope_data = {
#                 select_mlcw: {
#                     "MLCW_slope": mlcw_slope_cm_yr,
#                     "GPS_slope": gps_slope_cm_yr,
#                     "MLCW_GPS_ratio": (
#                         mlcw_slope_cm_yr / gps_slope_cm_yr
#                         if gps_slope_cm_yr != 0
#                         else None
#                     ),
#                 }
#             }
#
#             json_path = os.path.join(
#                 SAVEFIG_FLD, f"{select_mlcw}_slope_ratio.json"
#             )
#             with open(json_path, "w") as f:
#                 json.dump(slope_data, f, indent=4)
#
#     except Exception as e:
#         print(select_mlcw, gps_byMLCW, e)
#         print()
#         pass

# %% [markdown]
# **check MLCW ring-by-ring over GPS**

# %% [raw]
# # ---------------------------------------------------------
# # 1. Setup paths and input parameters
# # ---------------------------------------------------------
# MLCW_MODEL_FLD = "MLCW_modeled/"
# GPS_MODEL_FLD = "GPS_modeled/"
# PAIRS_EXCEL = "MLCW_GPS_pairs.xlsx"
#
# # ---------------------------------------------------------
# # 2. Find corresponding GPS station
# # ---------------------------------------------------------
# # Read the pairs and get the corresponding GPS station name
# station_pairs = pd.read_excel(PAIRS_EXCEL, index_col=[1])
# gps_byMLCW = station_pairs.loc[select_mlcw, "station_co"]
#
# # Select the MLCW station to analyze
# select_mlcw = "TUKU"
#
# # ---------------------------------------------------------
# # 3. Load Data
# # ---------------------------------------------------------
# # Find the first matching CSV for the MLCW station and read it
# mlcw_csv_path = glob(os.path.join(MLCW_MODEL_FLD, f"*{select_mlcw}*csv"))[0]
# mlcw_df = pd.read_csv(mlcw_csv_path, index_col=[0], parse_dates=[0]) * 1000
#
# # Find the first matching CSV for the GPS station and read it
# gps_csv_path = glob(os.path.join(GPS_MODEL_FLD, f"*{gps_byMLCW}*csv"))[0]
# gps_df = pd.read_csv(gps_csv_path, index_col=[0], parse_dates=[0]) * 1000
#
#
# # ---------------------------------------------------------
# # 4. Align Data to Mutual Timeframe
# # ---------------------------------------------------------
# def get_aligned_df(df, mutual_time):
#     """
#     Filter dataframe by mutual dates and shift values so the
#     first observation starts at 0 for a clean comparison baseline.
#     """
#     new_df = df.loc[mutual_time]
#     new_df = new_df.subtract(new_df.iloc[0, :], axis=1)
#     return new_df
#
#
# # Find intersection of dates between MLCW and GPS
# mutual_dates = mlcw_df.index.intersection(gps_df.index)
#
# # Align both dataframes to the mutual dates
# aligned_mlcw = get_aligned_df(df=mlcw_df, mutual_time=mutual_dates)
# aligned_gps = get_aligned_df(df=gps_df, mutual_time=mutual_dates)
#
# # Extract the 'modeled' column for GPS
# aligned_gps_arr = aligned_gps["modeled"]
#
# plt.plot(aligned_mlcw.div(aligned_gps_arr, axis=0) * 100)

# %% [raw]
# def get_mlcw_ref2base(mlcw_data, station_name):
#     depth_arr = mlcw_data[station_name]["depth"]
#     date_arr = pd.to_datetime(
#         [x.decode() for x in mlcw_data[station_name]["date"]]
#     )
#     ref2base_arr = mlcw_data[station_name]["values"]["ref2base"]
#     temp = pd.DataFrame(data=ref2base_arr, index=depth_arr, columns=date_arr)
#     total_compact_arr = temp.iloc[0, :]
#     total_compact_arr.name = station_name
#     return total_compact_arr
#
#
# def get_gps_timeseries(gps_folder, station_name):
#
#     found_file = glob(os.path.join(gps_folder, f"{station_name}*"))[0]
#
#     gps_df = pd.read_csv(found_file, index_col=[0], parse_dates=[0])
#
#     return gps_df["modeled"] * 1000  # convert to milimeters
#
# station_pairs = pd.read_excel("MLCW_GPS_pairs.xlsx", index_col=[0])
# mlcw_stations = sorted(station_pairs.index)
#
# select_mlcw_code = "MW_TKJS"
# mlcw_ename = station_pairs.loc[select_mlcw_code]["Ename"]
# gps_byMLCW = station_pairs.loc[select_mlcw_code]["station_co"]
#
# mlcw_ename, gps_byMLCW
#
# ref2base_byMLCW = get_mlcw_ref2base(
#     mlcw_data=mlcw_data, station_name=mlcw_ename
# )
#
# mlcw_data, mlcw_info = open_HDF5(
#     r"D:\1000_SCRIPTS\003_Project002\20251111_GTWR003\1_PrepareDatasets\MLCW_3\20251230_MLCW_CRFP_Imputed_v4.h5"
# )
# gps_source_fld = "GPS_modeled/"
#
# # - - - - - - - - - - - - - - - - - -
# ref2base_byMLCW = get_mlcw_ref2base(
#     mlcw_data=mlcw_data, station_name=mlcw_ename
# )
# # - - - - - - - - - - - - - - - - - -
# gps_byMLCW_modeled = get_gps_timeseries(
#     gps_folder=gps_source_fld, station_name=gps_byMLCW
# )
# # - - - - - - - - - - - - - - - - - -
#
# mutual_start_time = ref2base_byMLCW.index.intersection(
#     gps_byMLCW_modeled.index
# ).min()
#
# new_ref2base = ref2base_byMLCW.loc[mutual_start_time:]
# new_gps = gps_byMLCW_modeled.loc[mutual_start_time:]
#
# new_ref2base = new_ref2base.subtract(new_ref2base.iloc[0])
# new_gps = new_gps.subtract(new_gps.iloc[0])
#
# new_ref2base.subtract(new_ref2base.iloc[0])
#
# new_gps.subtract(new_gps.iloc[0])

# %% [markdown]
# ## Extract MLCW trend
#
# calculate the trend of modeled MLCW data, but only select station with data from 2010 to 2021, more than 5 years.

# %% [raw]
# mlcw_gdf = gpd.read_file(
#     r"D:\002_DATA\HSU_YARU_PROF\Yaru_work\mlcw_data_DavidNCU\mlcw_stations_TWD97.shp",
#     read_geometry=False,
# )
# mlcw_gdf = mlcw_gdf.loc[:, ["Ename", "X_TWD97", "Y_TWD97"]]
# mlcw_gdf = mlcw_gdf.sort_values(by="Ename").reset_index(drop=True)
# mlcw_gdf = mlcw_gdf.set_index("Ename")
# mlcw_gdf.head(3)

# %% [raw]
# mlcw_model_folder = "MLCW_modeled/"
#
# files = glob(os.path.join(mlcw_model_folder, "*csv"))
#
# cache = {"STATION": [], "AvgVelo_mmyr": []}
#
# f = files[0]
#
# for f in files:
#     station_name = os.path.basename(f).replace("_ringbyring.csv", "")
#
#     station_df = pd.read_csv(f, index_col=[0], parse_dates=[0])
#     df_subset = station_df.loc["2010":"2021", :]
#
#     if len(df_subset.index.year.unique()) > 5:
#
#         df_subset_totalcompaction = pd.DataFrame(
#             df_subset.sum(axis=1), columns=[station_name]
#         )
#
#         df_subset_totalcompaction = df_subset_totalcompaction.subtract(
#             df_subset_totalcompaction.iloc[0]
#         )
#         df_subset_totalcompaction = convert_to_fulltime(
#             df_subset_totalcompaction
#         )
#
#         totalcompaction_arr = df_subset_totalcompaction.iloc[:, 0]
#
#         _arr, trend_slope = analysis.get_linear_trend(
#             totalcompaction_arr, force_zero_intercept=False
#         )
#
#         mlcw_velocity = np.round(trend_slope * 365.25, 3)
#
#         cache["STATION"].append(station_name)
#         cache["AvgVelo_mmyr"].append(mlcw_velocity)

# %% [raw]
# output_df = pd.DataFrame(cache)
# output_df = output_df.set_index("STATION")
# output_df["X_TWD97"] = output_df.index.map(mlcw_gdf["X_TWD97"])
# output_df["Y_TWD97"] = output_df.index.map(mlcw_gdf["Y_TWD97"])
# output_geodata = convert_to_geodata(
#     output_df, xcoord_col="X_TWD97", ycoord_col="Y_TWD97", crs_epsg="EPSG:3826"
# )
# output_geodata.to_file("GPS_data/MLCW_avgvelocity_mmyr_TWD97.shp")
#
# # MLCW - InSAR

# %% [raw]
# savefig_folder = "output_figs"
#
# # --- 1. DATA LOADING & INITIALIZATION ---
#
# # Load the master InSAR time series shapefile
# # 'Ename' is used as the unique identifier for monitoring stations
# insar_master_gdf = gpd.read_file(
#     "InSAR_timeries/mlcw_interp_insar_IDW.shp", read_geometry=False
# ).set_index("Ename")
#
# # Define path to Multilayer Compaction Monitoring Well (MLCW) reconstruction files
# mlcw_directory = "MLCW_reconstruction/"
# well_files = glob(os.path.join(mlcw_directory, "*.csv"))
#
# # Select the first available well file for analysis
# # target_well_path = well_files[0]
# for target_well_path in well_files:
#     station_id = os.path.basename(target_well_path).replace(
#         "_ringbyring_reconstructed.csv", ""
#     )
#
#     # --- 2. MLCW DATA PREPROCESSING ---
#
#     # Load well data: index_col=[0] assumes the first column is the Date
#     raw_well_df = pd.read_csv(target_well_path, index_col=[0], parse_dates=[0])
#
#     # Filter for the specific study period (Feb 2015 to 2022)
#     well_compaction_subset = raw_well_df.loc["2015-02":"2021"]
#
#     # Baseline the data: Subtract the first row from all subsequent rows
#     # This calculates relative compaction change starting from zero
#     normalized_well_df = well_compaction_subset.subtract(
#         well_compaction_subset.iloc[0, :], axis=1
#     )
#
#     # Sum across all columns (layers) to get the cumulative vertical compaction for the well
#     total_well_compaction = normalized_well_df.sum(axis=1)
#
#     # --- 3. INSAR DATA PREPROCESSING ---
#
#     # Extract the InSAR time series row corresponding to our current well station
#     insar_station_raw = insar_master_gdf.loc[station_id, :]
#
#     # Filter InSAR dates and convert units (typically meters to millimeters)
#     # "D20150301" indexing assumes columns are named 'DYYYYMMDD'
#     insar_displacement_mm = insar_station_raw.loc["D20150301":] * 1000
#
#     # Clean the InSAR index: Remove the 'D' prefix and convert to standard datetime objects
#     insar_displacement_mm.index = pd.to_datetime(
#         [date_str[1:] for date_str in insar_displacement_mm.index]
#     )
#
#     # --- 4. TEMPORAL ALIGNMENT ---
#
#     # Identify dates where both the physical well sensors and InSAR satellites have data
#     common_dates = total_well_compaction.index.intersection(
#         insar_displacement_mm.index
#     )
#
#     # Synchronize both datasets to these mutual time steps
#     aligned_well_data = total_well_compaction.loc[common_dates]
#     aligned_insar_data = insar_displacement_mm.loc[common_dates]
#
#     # --- 5. VISUALIZATION (Object-Oriented Interface) ---
#
#     # Initialize the figure container
#     fig = plt.figure(figsize=(11.7, 5.5))
#
#     # Add a subplot (111 means 1x1 grid, 1st subplot)
#     ax = fig.add_subplot(111)
#
#     # Calculate and plot the ratio
#     # We use ax.plot rather than plt.plot for the OO approach
#     ax.plot(
#         aligned_well_data / aligned_insar_data,
#         marker="o",
#         linestyle="-",
#         color="darkcyan",
#         label="Compaction/Displacement Ratio",
#     )
#
#     # Add a horizontal line at 1.0 for reference (where compaction = InSAR displacement)
#     ax.axhline(
#         1.0,
#         color="red",
#         linestyle="--",
#         alpha=0.5,
#         label="Perfect Correlation (1.0)",
#     )
#
#     ax.set_ylim(-0.1, 1.5)
#
#     ax.grid(True, linestyle=":", alpha=0.7)
#     ax.legend()
#
#     visualize.configure_axis(
#         ax=ax,
#         hide_spines=["top", "right"],
#         ylabel="Ratio",
#         title=f"Compaction Analysis: {station_id}",
#         major_tick_length=10,
#         minor_tick_length=7,
#         tick_direction="out",
#     )
#
#     visualize.configure_ticks(ax=ax, y_major_interval=0.2, y_minor_interval=0.1)
#
#     visualize.configure_legend(ax=ax)
#
#     visualize.configure_datetime_ticks(ax=ax, fontsize=14, major_interval=6)
#
#     fig.autofmt_xdate(rotation=75, ha="center", bottom=0.05)
#
#     visualize.save_figure(
#         fig=fig,
#         savepath=os.path.join(savefig_folder, f"{station_id}_ratio.png"),
#     )
#
#     plt.close()

# %% [markdown]
# ## Get GPS velocity (Kriging) into MLCW points

# %% [markdown]
# **v1**

# %% [raw]
# fpath = "GPS_data/MLCW_GPS_velocity_TWD97_v2.shp"
# gdf = gpd.read_file(fpath, read_geometry=True)
# gdf = gdf.rename({"AvgVelo_mm": "MLCW_mmyr", "Predicted": "GPS_mmyr"}, axis=1)
# gdf["Ratio"] = np.round(gdf["MLCW_mmyr"] / gdf["GPS_mmyr"], 3)
# gdf = gdf.loc[
#     :,
#     [
#         "STATION",
#         "MLCW_mmyr",
#         "GPS_mmyr",
#         "Ratio",
#         "X_TWD97",
#         "Y_TWD97",
#         "geometry",
#     ],
# ]
#
# # show(gdf)
# gdf.to_file(fpath)

# %% [raw]
# gdf.iloc[:, :-1].to_csv(r"MLCW_GPS_velocity_TWD97_v2.csv", index=False)

# %% [markdown]
# **v2**

# %% [markdown]
# # Extract GPS trend (2025/5/7)
#
# Then perform interpolation with CoKriging, using leveling-derived slope as secondary data set

# %% [raw]
# gps_geodata = gpd.read_file("GPS_data/TGM_GPS_WGS84.shp", read_geometry=False)
# gps_geodata = gps_geodata.set_index("station_co")
# gps_geodata.head(3)

# %% [raw]
# gps_source_fld = "GPS_decomposition/"
#
# files = glob(os.path.join(gps_source_fld, "*", "*.csv"))
#
# files[:5]

# %% [raw]
# cache = {"STATION": [], "AvgVelo_mmyr": []}
#
# for gps_fpath in files[:]:
#
#     station_name = gps_fpath.split("\\")[1].replace("_neu", "")
#
#     df = pd.read_csv(
#         gps_fpath, index_col=[0], parse_dates=[0], usecols=[0, 1, 2]
#     )
#     df = df.loc["2010":"2021", :] # added, on 2026/5/8
#     N = len(df.index.year.unique()) # added, on 2026/5/8
#     if N >= 5: # added, on 2026/5/8
#         trend_arr = df["dU_trend"]
#         trend_arr = trend_arr.subtract(trend_arr[0])
#         _arr, trend_slope = analysis.get_linear_trend(
#             trend_arr, force_zero_intercept=False
#         )
#         velocity_mmyr = np.round(trend_slope * 365.25, 2)
#
#         cache["STATION"].append(station_name)
#         cache["AvgVelo_mmyr"].append(velocity_mmyr)
#
# output_velocity_df = pd.DataFrame(cache)
# output_velocity_df = output_velocity_df.set_index("STATION")
# output_velocity_df["long"] = output_velocity_df.index.map(gps_geodata["long"])
# output_velocity_df["lat"] = output_velocity_df.index.map(gps_geodata["lat"])
#
# output_velocity_df = output_velocity_df.reset_index()
#
# output_gdf = geospatial.convert_to_geodata(
#     df=output_velocity_df,
#     xcoord_col="long",
#     ycoord_col="lat",
#     crs_epsg="EPSG:4326",
# )
# output_gdf.to_file(r"GPS_avgvelocity_mmyr_WGS84_v2.shp")
# # output_velocity_df = output_velocity_df.astype({"STATION":str})
# # output_velocity_df.to_csv("GPS_data/GPS_avgvelocity_mmyr_WGS84_v2.csv", index=False)

# %% [raw]
# output_gdf.to_file("GPS_data/GPS_avgvelocity_mmyr.shp")

# %% [markdown]
# # Turn IDW interpolated shapefiles to feather files

# %% [raw]
# import geopandas as gpd
# from pyproj import Transformer
#
#
# def convert_utm_to_twd97(fpath):
#     """
#     Reads a spatial file, converts coordinates from EPSG:32650 to EPSG:3826,
#     and returns a DataFrame with reordered columns.
#     """
#     # 1. Load the data
#     # read_geometry=False converts the GeoDataFrame to a standard pandas DataFrame
#     df = gpd.read_file(fpath, ignore_geometry=True)
#
#     # 2. Initialize the Transformer
#     # From WGS 84 / UTM zone 50N to TWD97 / TM2 zone 121
#     transformer = Transformer.from_crs(
#         "EPSG:32650", "EPSG:3826", always_xy=True
#     )
#
#     # 3. Perform the conversion
#     # We use .values for speed (vectorized operation)
#     df["X_TWD97"], df["Y_TWD97"] = transformer.transform(
#         df["X_UTM50N"].values, df["Y_UTM50N"].values
#     )
#
#     # 4. Reorder columns
#     # Separate info columns from measurement columns (those starting with 'D')
#     info_cols = [col for col in df.columns if not col.startswith("D")]
#     measures_cols = [col for col in df.columns if col.startswith("D")][1:]
#
#     new_cols = info_cols + measures_cols
#
#     return df[new_cols]
#
#
# # --- Usage ---
# fpath = "InSAR_timeries/mlcw_interp_insar_IDW_extend.gpkg"
# basename = os.path.basename(fpath)
# savename = basename.replace(".gpkg", ".feather")
#
# output_df = convert_utm_to_twd97(fpath)
#
# # Preview the result
# output_df.to_feather(f"InSAR_timeries/{savename}")

# %% [raw]
# fpath = r"InSAR_timeries/gridpnt_500m_interp_insar_IDW_extend.gpkg"
#
# gdf = gpd.read_file(fpath, read_geometry=False)
# gdf = gdf.drop(columns=["D20150116"])
# outpath = fpath.replace(".gpkg", ".feather")
# gdf.to_feather(outpath)

# %% [markdown]
# # Extract 5-m regular time series from 2015 onward

# %% [raw]
# folder = "MLCW_5m_regular/"
#
# savefolder = "MLCW_5m_regular_2015/"
#
# files = glob(os.path.join(folder, "*csv"))
#
# # f = files[0]
# for f in tqdm(files):
#     base = os.path.basename(f)
#
#     df = pd.read_csv(f, parse_dates=[0], index_col=[0])
#     subset = df.loc["2015-1-16":, :]
#     subset = subset.subtract(subset.iloc[0, :], axis=1)
#     subset = subset.iloc[1:, :]
#     subset = np.round(subset, 3)
#
#     subset.to_csv(os.path.join(savefolder, base))

# %% [markdown]
# # Interpolate MLCW/GPS ratio to short-time points
#
# the file `MLCW_GPS_velocity_TWD97_v2.csv` only contains 33 points, because I exclude the stations with observation time < 5 years
#
# therefore, I interpolated the values of ratio from `MLCW_GPS_velocity_TWD97_v2.shp` using radial basis function, method file saved in `ratio_RBF.lyr`

# %% [raw]
# fpath = "GPS_data/MLCW_interpolated_ratio.shp"
# gdf = gpd.read_file(fpath, read_geometry=False)
# gdf = gdf.rename({"Predicted":"Imputed_Ratio"}, axis=1)
# gdf.to_csv(r"ratio_MLCW_over_GPS_interpolated.csv", index=False)
# gdf.head(3)

# %% [raw]
# fpath = "GPS_data/MLCW_interpolated_ratio_RBF.shp"
# gdf = gpd.read_file(fpath, read_geometry=False)
# gdf = gdf.rename({"Predicted": "Imputed_Ratio"}, axis=1)
# gdf.to_csv(r"ratio_MLCW_over_GPS_RBF_interpolated.csv", index=False)
# gdf.head(3)

# %% [markdown]
# # MLCW and InSAR tasks

# %% [markdown]
# ## Add coordinates into alpha ratio output from `alpha_insar_test.py`

# %% [raw]
# alpha_fpath = "alpha_comparison_all_stations_v1.csv"
# alpha_df = pd.read_csv(alpha_fpath, index_col=["Ename"])
# alpha_df = alpha_df.dropna(axis=1, how="all")
#
# coordiate_df = pd.read_feather(
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\InSAR_timeries\mlcw_interp_insar_IDW_extend.feather"
# )
# coordiate_df = coordiate_df.set_index("Ename")
#
# alpha_df["X_TWD97"] = alpha_df.index.map(coordiate_df["X_TWD97"])
# alpha_df["Y_TWD97"] = alpha_df.index.map(coordiate_df["Y_TWD97"])
#
# alpha_df.to_csv("alpha_comparison_all_stations_v2.csv") # not yet remove weird alpha stations
#
# # after removing stations with weird alpha --> version 3

# %% [markdown]
# ## Turn to shapefile

# %% [raw]
# alpha_df = pd.read_csv("alpha_comparison_all_stations_v2.csv")
# alpha_gdf = convert_to_geodata(
#     df=alpha_df,
#     xcoord_col="X_TWD97",
#     ycoord_col="Y_TWD97",
#     crs_epsg="EPSG:3826",
# )
# alpha_gdf.to_file("GPS_data/alpha_comparison_all_stations_v2.gpkg")

# %% [markdown]
# # GROUNDWATER LEVEL DATA SET

# %% [raw]
# from appgeopy import *
# from my_packages import *
#
# fpath = r"D:\1000_SCRIPTS\004_Project003\20251229_Gwater_Levels\20260108_GWL_CRFP_daily_modeled.h5"
#
# gwl_data, gwl_info = gwatertools.open_HDF5(fpath)

# %% [raw]
# print(type(gwl_data), type(gwl_info))

# %% [raw]
# print(gwl_data.keys())

# %% [raw]
# print(gwl_info.keys())

# %% [raw]
# folder = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\GroundwaterWells_MaterialAssign"
#
# txt_files = [
#     os.path.basename(f).split(".")[0]
#     for f in glob(os.path.join(folder, "*.txt"))
# ]
# png_files = [
#     os.path.basename(f).split(".")[0]
#     for f in glob(os.path.join(folder, "*.png"))
# ]

# %% [raw]
# set(txt_files).difference(set(png_files))

# %% [raw]
# gwl_gdf = gpd.read_file(
#     r"D:\1000_SCRIPTS\004_Project003\20260115_InSAR_2015_2025\studyarea_shapefiles\GWL_unique_wells_2026.geojson"
# )
# station = gwl_gdf["STATION"].unique()
#
# set(station).difference(set(txt_files))

# %% [raw]
# fpath = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\gwl_inspection\gwl_allwells_flat.csv"
# df = pd.read_csv(fpath)
# df = df.dropna(axis=1, how='all')
# df.to_excel(fpath.replace(".csv", ".xlsx"), index=False)

# %% [raw]
# fpath = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\gwl_inspection\well_info_screen_comparison.csv"
# df = pd.read_csv(fpath)
# print(df.shape)
# df = df.dropna(axis=1, how='all')
# print(df.shape)
# df.to_excel(fpath.replace("csv", "xlsx"), index=False)

# %% [raw]
# fpath = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\gwl_inspection\well_info_combined.csv"
# df = pd.read_csv(fpath)
# df = df.dropna(axis=1, how='all')
# df.to_excel(fpath.replace("csv", "xlsx"), index=False)
# gdf = convert_to_geodata(df=df, xcoord_col="x_twd97", ycoord_col="y_twd97", crs_epsg="EPSG:3826")
# gdf.to_file(fpath.replace("csv", "gpkg"))

# %% [raw]
# fpath = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\gwl_inspection\well_info_combined.gpkg"
# gdf = gpd.read_file(fpath)
# temp = gdf[gdf["screen_raw"]!="-"]
# temp.to_file(fpath.replace(".gpkg", "_screenAvail.gpkg"))

# %% [markdown]
# # group MLCW by aquifers/aquitards

# %% [markdown]
# ## group the reconstructed timeseries
#
# to reduce the complexity of the problem, we will try to group magnetic rings into group

# %%
# ==============================================================================
# 1. LOAD MASTER MLCW STATION METADATA FROM HDF5
# ==============================================================================

# File path to the pre-processed, imputed Multilayer Compaction Well (MLCW) master dataset
h5_fpath = r"D:\1000_SCRIPTS\003_Project002\20251111_GTWR003\1_PrepareDatasets\MLCW_3\20251230_MLCW_CRFP_Imputed_v4.h5"

# Load the HDF5 data payload and metadata attributes using specialized groundwater tools
mlcw_data, mlcw_info = gwatertools.open_HDF5(h5_fpath)

# Extract valid station identifiers (keys containing dictionary structures) from the HDF5 file
available_stations = [
    ele for ele in mlcw_data.keys() if isinstance(mlcw_data[ele], dict)
]
# Preview the first 5 available groundwater monitoring stations (e.g., TUKU)
available_stations[:5]
# Out:
# ['ANHE', 'ANNAN', 'BEICHEN', 'CANLIN', 'DONGGUANG']

# %%
# ==============================================================================
# 2. LOCATE RECONSTRUCTED TIMESERIES DATA (InSAR-MLCW COUPLING PROJECT)
# ==============================================================================

# Folder containing reconstructed MLCW time-series data files associated with InSAR processing
# mlcw_reconst_fld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\reconstructed"

# 2026-5-27, change to modeled timeseries, to keep the original timeline
# mlcw_reconst_fld = (
#     r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\modeled"
# )

# 2026-6-1
mlcw_reconst_fld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\modeled_nojump\nojump"

# ------------------------------------------------------------------------------
# PURPOSE: DEFINE OUTPUT DIRECTORY AND ENSURE STORAGE PATH EXISTS
# ------------------------------------------------------------------------------

# Define the destination folder for storing aggregated layer-by-layer compaction datasets
# output_savefld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\group_byLayer_modeled"
output_savefld = r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\mlcw\modeled_nojump\group_byLayer_nojump"

# Create the target directory automatically if it does not already exist
if not os.path.exists(output_savefld):
    os.makedirs(output_savefld, exist_ok=True)

# Gather paths of all reconstructed station text files (.csv format) inside the target directory
mlcw_reconst_files = glob(os.path.join(mlcw_reconst_fld, "*csv"))
# Quick check on the first 3 file paths
mlcw_reconst_files[:3]
# Out:
# ['D:\\1000_SCRIPTS\\004_Project003\\20260427_InSAR_MLCW_v2\\data\\mlcw\\modeled_nojump\\nojump\\ANHE_ringbyring.csv',
#  'D:\\1000_SCRIPTS\\004_Project003\\20260427_InSAR_MLCW_v2\\data\\mlcw\\modeled_nojump\\nojump\\ANNAN_ringbyring.csv',
#  'D:\\1000_SCRIPTS\\004_Project003\\20260427_InSAR_MLCW_v2\\data\\mlcw\\modeled_nojump\\nojump\\BEICHEN_ringbyring.csv']

# %%
# ------------------------------------------------------------------------------
# PURPOSE: BATCH-PROCESS ALL AVAILABLE STATIONS ACROSS THE CHOUSHUI RIVER ALLUVIAL FAN
# ------------------------------------------------------------------------------

# Iterate systematically through every available monitoring station using a progress bar
for select_station in tqdm(available_stations):
    try:
        # Match and retrieve the reconstructed time-series CSV file path for the active station
        mlcw_reconst_fpath = [
            f for f in mlcw_reconst_files if select_station in f
        ][0]

        # Extract depth values and binary-encoded layer information from the station's HDF5 schema
        classify_byStation = mlcw_data[select_station]["classify"]
        depth_arr = np.round(classify_byStation["depth"], 3)

        # Decode binary/byte layer names into standard, readable UTF-8 strings
        layer_arr = [ele.decode("utf-8") for ele in classify_byStation["layer"]]

        # Construct a reference dataframe mapping sensor anchor depths to specific hydrogeological layers
        classify_df = pd.DataFrame(
            data={"depth": depth_arr, "layer": layer_arr}
        )
        classify_df = classify_df.astype("str")

        # Generate an ordered sequence of unique aquifer/aquitard layers monitored at this well site
        all_layers = classify_df["layer"].unique()

        # ------------------------------------------------------------------------------
        # PURPOSE: AGGREGATE SENSOR COMPACTION DATA BY HYDROGEOLOGICAL LAYERS
        # ------------------------------------------------------------------------------

        # Load the station's historical timeseries data, initializing the timestamp column as a DatetimeIndex
        mlcw_reconst_df = pd.read_csv(
            mlcw_reconst_fpath, index_col=[0], parse_dates=[0]
        )

        # Instantiate a tracking list for processed depths and a fresh container for aggregated layer values
        cache = []
        output_mlcw_byLayer = pd.DataFrame(data=None, index=None)

        # Loop through each classified layer to sum up individual multi-depth sensor readings
        for idx, select_layer in enumerate(all_layers[:]):

            # Final-Layer Safeguard: Assign any remaining unmapped depths to the bottom layer
            # to ensure strict continuity and zero tracking omissions.
            if idx == (len(all_layers) - 1):
                depth_to_extract = mlcw_reconst_df.columns.difference(cache)
                depth_byLayer_str = classify_df.query(
                    "depth in @depth_to_extract"
                )["depth"].tolist()

            # Standard Operation: Isolate sensor depths explicitly designated for the current active layer
            else:
                depth_byLayer_str = classify_df.query("layer==@select_layer")[
                    "depth"
                ].tolist()

            # Slice displacement columns and sum them horizontally to establish a cumulative layer-wide metric
            mlcw_byDepth = mlcw_reconst_df.loc[:, depth_byLayer_str]
            mlcw_byDepth_sum = mlcw_byDepth.sum(axis=1)
            mlcw_byDepth_sum.name = select_layer

            # Horizontally merge the current layer's time-series into the active processing DataFrame
            output_mlcw_byLayer = pd.concat(
                [output_mlcw_byLayer, mlcw_byDepth_sum], axis=1
            )

            # Log these processed sensor depths into the cache to mask them in the final iteration loop
            cache.extend(depth_byLayer_str)

        # ------------------------------------------------------------------------------
        # PURPOSE: FORMAT DATAFRAMES AND EXPORT PRODUCTION DATASETS TO DISK
        # ------------------------------------------------------------------------------

        # Flatten the DatetimeIndex back into a normal column and rename it formally to "datetime"
        output_mlcw_byLayer = output_mlcw_byLayer.reset_index()
        output_mlcw_byLayer = output_mlcw_byLayer.rename(
            {"index": "datetime"}, axis=1
        )

        # Save the processed layer-by-layer cumulative compaction time-series dataset to a CSV file
        output_mlcw_byLayer.to_csv(
            os.path.join(
                # output_savefld, f"{select_station}_reconst_grouped.csv"
                output_savefld,
                f"{select_station}_modeled_grouped.csv",
            ),
            index=False,
        )

        # Export the standalone hydrogeological stratigraphy/depth mapping table for future model reference
        classify_df.to_csv(
            os.path.join(
                output_savefld, f"{select_station}_classify_table.csv"
            ),
            index=False,
        )
    except Exception as e:
        print(select_station, e)
        pass
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# JINHU_XIN "None of [Index(['1.41', '7.153', '19.145', '27.15', '35.126', '42.634'], dtype='object')] are in the [columns]"
# LUNFENG_XIN "['14.823'] not in index"

# %% [markdown]
# # .

# %%
pd.read_feather(
    r"D:\1000_SCRIPTS\004_Project003\20260427_InSAR_MLCW_v2\data\gwl\well_timeseries\TUKU_gwl_timeseries.feather"
)
